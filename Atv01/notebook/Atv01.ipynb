// %% [markdown]
// # Atv01

// %% [markdown]
// Apresente a soma de todos os argumentos inteiros ou reais recebidos

// %%
import java.util.Scanner;
Scanner s = new Scanner(System.in);
int soma = 0, i, y;
System.out.println("Dgite dois números inteiros: ");
System.out.print("Digite o primeiro valor inteiro: ");
i = s.nextInt();
System.out.print("Digite o segundo valor inteiro: ");
y = s.nextInt();
soma = i + y;
System.out.println("O valor da soma é: " +soma); 
       
s.close();
// Out:
// Dgite dois números inteiros:
// Digite o primeiro valor inteiro: 2
// Digite o segundo valor inteiro: 8
// O valor da soma é: 10
// null
