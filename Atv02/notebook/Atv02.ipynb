// %% [markdown]
// # Atv02

// %% [markdown]
// Exibir a mensagem “Informe um inteiro: “, deixando o cursor na mesma linha

// %%
System.out.print("Informe um número interio: "); //solicita que o usuário digite um número interio
int i = System.in.read(); //aguarda a digitação do número já definindo que o mesmo será lido e armazenado como inteiro
// Out:
// Informe um número interio: 9
// null

// %% [markdown]
// Atribuir o produto das variáveis b e c para a variável a

// %%
import java.util.Scanner;
Scanner s = new Scanner(System.in);

int a = 0, b = 2, c = 6;

a = b * c;

System.out.println(a);

s.close();
// Out:
// 12
// null

// %% [markdown]
// Demonstrar a execução do cálculo e utilizar um comentário para afirmar que é um programa de exemplo de folha de pagamento.

// %%
import java.util.Scanner;

Scanner s = new Scanner(System.in);
int a = 0, b, c;
System.out.print("Digite o valor da diária: ");
b = s.nextInt();
System.out.print("Digite número de dias trabalhados: ");
c = s.nextInt();
a = b * c;
System.out.println("O valor a receber pelos dias trabalhados é: " +a);

s.close();
// Out:
// Digite o valor da diária: 360
// Digite número de dias trabalhados: 18
// O valor a receber pelos dias trabalhados é: 6480
// null
